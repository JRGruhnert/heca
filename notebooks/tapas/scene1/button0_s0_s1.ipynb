# %%
from heca.experts.tapas import TapasExpert
from conf.experts.scene1 import button0_s0_s1 as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# 2026-08-17 01:27:51.241 | INFO     |  Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/riepybdlib/data.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_listdir
# 2026-08-17 01:27:53.289 | INFO     | heca.misc.logger:info:37 - Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
agent = TapasExpert.get(agent_cfg)
# Out:
# 2026-08-17 01:27:54.278 | INFO     | heca.misc.logger:info:37 - Loading <class 'heca.experts.tapas.TapasExpert'> from /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 01:27:54.278 | INFO     | tapas_gmm_modified.utils.logging:wrapper:67 - Initializing Policy:
# 2026-08-17 01:27:54.278 | INFO     | tapas_gmm_modified.encoder:get_image_encoder_class:62 - No encoder config provided. Using None.
# 2026-08-17 01:27:54.279 | WARNING  | heca.misc.logger:warning:33 - No tapas policy found at given path: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/button0_s0_s1/policy_gt.pt

# %%
demos = agent.load_demos(segment_ids)
# Out:
# 2026-08-17 01:27:55.427 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# n_trajs 5
# n_frames 12

# %%
agent.fit_stage1(demos)
# Out:
# 2026-08-17 01:27:55.433 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 01:27:55.433 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 01:27:55.433 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2860 - Segmenting trajectories
# 2026-08-17 01:27:55.725 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2697 - Creating segement of demos.
# 2026-08-17 01:27:55.726 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# 2026-08-17 01:27:55.726 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2865 - ... created 1 segments
# 2026-08-17 01:27:55.727 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 1/12
# 2026-08-17 01:27:55.727 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 01:27:55.727 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# 2026-08-17 01:27:55.728 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 01:27:55.728 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 01:27:55.728 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 01:27:55.728 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 01:27:55.870 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 2/12
# 2026-08-17 01:27:55.870 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 01:27:55.870 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# 2026-08-17 01:27:55.872 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 01:27:55.872 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 01:27:55.872 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 01:27:55.872 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 01:27:56.034 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 3/12
# 2026-08-17 01:27:56.034 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 01:27:56.035 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# 2026-08-17 01:27:56.037 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 01:27:56.037 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 01:27:56.037 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 01:27:56.037 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 01:27:56.204 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 4/12
# 2026-08-17 01:27:56.204 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 01:27:56.204 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# 2026-08-17 01:27:56.206 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 01:27:56.206 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 01:27:56.206 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 01:27:56.206 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 01:27:56.391 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 5/12
# 2026-08-17 01:27:56.391 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 01:27:56.391 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 36 using strategy mean-length.
# 2026-08-17 01:27:56.393 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17
| INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2961 - Frame score (rel):
#            ee_init   button0    shelf0   faucet0   faucet1         cube0  \
# Segment 0      1.0  0.256168  0.256168  0.000005  0.000517  1.863362e-07
#
#            button0_target  shelf0_target  faucet0_target  faucet1_target  \
# Segment 0        0.256168       0.256168        0.000014         0.00001
#
#            cube0_target  ee_target
# Segment 0  3.562794e-10   0.564012
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 01:27:58.197 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R3 x QUAT x R1
# 2026-08-17 01:27:58.197 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 01:27:58.197 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 01:27:58.197 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
agent.plot_stage1()
# Out:
# 2026-08-17 01:27:58.492 | INFO     | tapas_gmm_modified.policy.models.tpgmm:plot_model:3856 - Did not specify time_based, deciding automatically.

# %%
agent.fit_stage2(demos)
# Out:
# 2026-08-17 01:28:00.134 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 01:28:00.135 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 01:28:00.138 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# 2026-08-17 01:28:00.138 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_hmm:1296 - HMM EM ...
# 2026-08-17 01:28:00.143 | INFO     | riepybdlib.statistics:trans:1710 - HMM transition matrix not defined, initializing to uniform
# HMM EM:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-08-17 01:28:00.198 | INFO     | riepybdlib.statistics:init_priors:1698 - HMM init priors not defined, initializing to uniform
# 2026-08-17 01:28:37.090 | WARNING  | riepybdlib.statistics:em:2262 - HMM EM did not converge

# %%
agent.plot_stage2()

# %%
agent.save()
# Out:
# 2026-08-17 01:28:38.519 | INFO     | heca.misc.logger:info:37 - Saving <class 'heca.experts.tapas.TapasExpert'> to /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 01:28:38.520 | INFO     | heca.misc.logger:info:37 - Saving tapas policy to: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/button0_s0_s1/policy_gt.pt
# 2026-08-17 01:28:38.520 | INFO     | tapas_gmm_modified.policy.models.tpgmm:to_disk:2617 - Saving model:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.save()
#
# File ~/Documents/GitHub/heca/src/heca/misc/base.py:152, in Persistable.save(self)
#     150 path = self.save_dir(self.cfg)
#     151 logger.info(f"Saving {type(self)} to {path}")
# --> 152 self._save(path)
#
# File ~/Documents/GitHub/heca/src/heca/experts/tapas.py:206, in TapasExpert._save(self, path)
#     204 filepath = path / "experts" / self.cfg.tag / file_name
#     205 logger.info(f"Saving tapas policy to: {filepath}")
# --> 206 self.model.to_disk(str(filepath))
#
# File ~/miniconda3/envs/hecarim/lib/python3.10/site-packages/tapas_gmm_modified/policy/models/tpgmm.py:2619, in TPGMM.to_disk(self, file_name)
#    2616 def to_disk(self, file_name: str) -> None:
#    2617     logger.info("Saving model:")
# -> 2619     with open(file_name, "wb") as f:
#    2620         pickle.dump(self, f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/button0_s0_s1/policy_gt.pt'
