# %%
from heca.experts.tapas import TapasExpert
from conf.experts.scene1 import cube0_base_base as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# 2026-08-17 14:01:45.540 | INFO     |  Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/riepybdlib/data.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_listdir
# 2026-08-17 14:01:48.165 | INFO     | heca.misc.logger:info:37 - Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
agent = TapasExpert.get(agent_cfg)
# Out:
# 2026-08-17 14:01:49.310 | INFO     | heca.misc.logger:info:37 - Loading <class 'heca.experts.tapas.TapasExpert'> from /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 14:01:49.310 | INFO     | tapas_gmm_modified.utils.logging:wrapper:67 - Initializing Policy:
# 2026-08-17 14:01:49.310 | INFO     | tapas_gmm_modified.encoder:get_image_encoder_class:62 - No encoder config provided. Using None.
# 2026-08-17 14:01:49.311 | WARNING  | heca.misc.logger:warning:33 - No tapas policy found at given path: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/cube0_base_base/policy_gt.pt

# %%
demos = agent.load_demos(segment_ids)
# Out:
# 2026-08-17 14:01:52.864 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# n_trajs 5
# n_frames 12

# %%
agent.fit_stage1(demos)
# Out:
# 2026-08-17 14:01:52.874 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 14:01:52.875 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:52.875 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2860 - Segmenting trajectories
# 2026-08-17 14:01:53.287 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(30, dtype=torch.int32), tensor(39, dtype=torch.int32), tensor(78, dtype=torch.int32)) from traj 1 of len 108
# 2026-08-17 14:01:53.287 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(33, dtype=torch.int32), tensor(76, dtype=torch.int32)) from traj 2 of len 106
# 2026-08-17 14:01:53.287 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(33, dtype=torch.int32), tensor(78, dtype=torch.int32)) from traj 3 of len 105
# 2026-08-17 14:01:53.287 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(31, dtype=torch.int32), tensor(76, dtype=torch.int32), tensor(88, dtype=torch.int32)) from traj 4 of len 104
# 2026-08-17 14:01:53.287 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2697 - Creating segement of demos.
# 2026-08-17 14:01:53.288 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:53.289 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2865 - ... created 1 segments
# 2026-08-17 14:01:53.289 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 1/12
# 2026-08-17 14:01:53.289 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:53.289 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:53.291 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:53.291 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:53.291 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:53.291 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:53.598 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 2/12
# 2026-08-17 14:01:53.598 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:53.599 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:53.600 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:53.600 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:53.600 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:53.600 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:54.112 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 3/12
# 2026-08-17 14:01:54.112 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:54.112 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:54.114 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:54.114 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:54.114 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:54.115 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:54.600 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 4/12
# 2026-08-17 14:01:54.601 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:54.601 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:54.602 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:54.602 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:54.603 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:54.603 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:55.067 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 5/12
# 2026-08-17 14:01:55.068 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:55.068 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:55.069 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:55.069 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:55.070 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:55.070 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:55.835 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 6/12
# 2026-08-17 14:01:55.836 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:55.836 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:55.837 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:55.838 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:55.838 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:55.838 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:56.639 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 7/12
# 2026-08-17 14:01:56.639 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:56.639 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:56.641 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:56.641 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:56.641 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:56.641 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:57.078 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 8/12
# 2026-08-17 14:01:57.078 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:57.078 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:57.080 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:57.080 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:57.080 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:57.080 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:57.516 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 9/12
# 2026-08-17 14:01:57.516 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:57.516 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:57.518 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:57.518 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:57.518 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:57.518 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:57.980 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 10/12
# 2026-08-17 14:01:57.981 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:57.981 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:57.982 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:57.983 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:57.983 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:57.983 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:58.083 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.138 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.205 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.249 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.317 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.381 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.437 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.500 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.549 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.648 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.719 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.806 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.914 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:58.986 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:59.059 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:01:59.302 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 11/12
# 2026-08-17 14:01:59.303 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:59.303 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:59.304 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:59.304 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:59.304 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:59.305 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:01:59.977 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 12/12
# 2026-08-17 14:01:59.977 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:01:59.977 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:01:59.979 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:01:59.979 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:01:59.979 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:01:59.979 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:02:00.298 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_init    score (rel):     -1 (1.000)
# 2026-08-17 14:02:00.298 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button0    score (rel):     -0 (0.232)
# 2026-08-17 14:02:00.298 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - shelf0     score (rel):     -0 (0.232)
# 2026-08-17 14:02:00.298 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet0    score (rel):     -0 (0.000)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet1    score (rel):     -0 (0.000)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - cube0      score (rel):     -0 (0.001)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button0_target score (rel):     -0 (0.232)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - shelf0_target score (rel):     -0 (0.232)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet0_target score (rel):     -0 (0.000)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet1_target score (rel):     -0 (0.000)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - cube0_target score (rel):     -0 (0.000)
# 2026-08-17 14:02:00.299 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_target  score (rel):     -1 (0.979)
# 2026-08-17 14:02:00.299 | WARNING  | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2914 - Using manual frame selection for debugging.
# 2026-08-17 14:02:00.300 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:02:00.300 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 84 using strategy mean-length.
# 2026-08-17 14:02:00.301 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2941 - Segmented trajs into 1 segments
# 2026-08-17 14:02:00.303 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2960 - Frame score (abs):
#             ee_init   button0    shelf0   faucet0  faucet1     cube0  \
# Segment 0 -0.973289 -0.226091 -0.226091 -0.000083 -0.00015 -0.000579
#
#            button0_target  shelf0_target  faucet0_target  faucet1_target  \
# Segment 0       -0.226091      -0.226091       -0.000139   -1.152591e-07
#
#            cube0_target  ee_target
# Segment 0     -0.000009  -0.952701
# 2026-08-17 14:02:00.305 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2961 - Frame score (rel):
#            ee_init   button0    shelf0   faucet0   faucet1     cube0  \
# Segment 0      1.0  0.232295  0.232296  0.000085  0.000154  0.000594
#
#            button0_target  shelf0_target  faucet0_target  faucet1_target  \
# Segment 0        0.232295       0.232296        0.000143    1.184223e-07
#
#            cube0_target  ee_target
# Segment 0      0.000009   0.978847
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 14:02:00.311 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R3 x QUAT x R1
# 2026-08-17 14:02:00.311 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:02:00.311 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:02:00.311 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
agent.plot_stage1()
# Out:
# 2026-08-17 14:02:01.767 | INFO     | tapas_gmm_modified.policy.models.tpgmm:plot_model:3856 - Did not specify time_based, deciding automatically.

# %%
agent.fit_stage2(demos)
# Out:
# 2026-08-17 14:02:03.826 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 14:02:03.827 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 14:02:03.831 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# 2026-08-17 14:02:03.831 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_hmm:1296 - HMM EM ...
# 2026-08-17 14:02:03.839 | INFO     | riepybdlib.statistics:trans:1710 - HMM transition matrix not defined, initializing to uniform
# HMM EM:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-08-17 14:02:03.983 | INFO     | riepybdlib.statistics:init_priors:1698 - HMM init priors not defined, initializing to uniform
# 2026-08-17 14:02:16.228 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:20.886 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:27.248 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:29.514 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:36.070 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:41.109 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:43.179 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:45.368 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:50.279 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:53.590 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:02:58.386 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:03:01.084 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 14:03:02.721 | INFO     | riepybdlib.statistics:em:2249 - HMM EM converged

# %%
agent.plot_stage2()

# %%
agent.save()
# Out:
# 2026-08-17 14:03:05.149 | INFO     | heca.misc.logger:info:37 - Saving <class 'heca.experts.tapas.TapasExpert'> to /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 14:03:05.149 | INFO     | heca.misc.logger:info:37 - Saving tapas policy to: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/cube0_base_base/policy_gt.pt
# 2026-08-17 14:03:05.149 | INFO     | tapas_gmm_modified.policy.models.tpgmm:to_disk:2617 - Saving model:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.save()
#
# File ~/Documents/GitHub/heca/src/heca/misc/base.py:152, in Persistable.save(self)
#     150 path = self.save_dir(self.cfg)
#     151 logger.info(f"Saving {type(self)} to {path}")
# --> 152 self._save(path)
#
# File ~/Documents/GitHub/heca/src/heca/experts/tapas.py:206, in TapasExpert._save(self, path)
#     204 filepath = path / "experts" / self.cfg.tag / file_name
#     205 logger.info(f"Saving tapas policy to: {filepath}")
# --> 206 self.model.to_disk(str(filepath))
#
# File ~/miniconda3/envs/hecarim/lib/python3.10/site-packages/tapas_gmm_modified/policy/models/tpgmm.py:2619, in TPGMM.to_disk(self, file_name)
#    2616 def to_disk(self, file_name: str) -> None:
#    2617     logger.info("Saving model:")
# -> 2619     with open(file_name, "wb") as f:
#    2620         pickle.dump(self, f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/cube0_base_base/policy_gt.pt'
