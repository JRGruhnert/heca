# %%
from heca.experts.tapas import TapasExpert
from conf.experts.scene1 import faucet0_b_a as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# 2026-08-17 13:59:41.531 | INFO     |  Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/riepybdlib/data.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_listdir
# 2026-08-17 13:59:43.772 | INFO     | heca.misc.logger:info:37 - Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
agent = TapasExpert.get(agent_cfg)
# Out:
# 2026-08-17 13:59:44.836 | INFO     | heca.misc.logger:info:37 - Loading <class 'heca.experts.tapas.TapasExpert'> from /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 13:59:44.836 | INFO     | tapas_gmm_modified.utils.logging:wrapper:67 - Initializing Policy:
# 2026-08-17 13:59:44.836 | INFO     | tapas_gmm_modified.encoder:get_image_encoder_class:62 - No encoder config provided. Using None.
# 2026-08-17 13:59:44.836 | WARNING  | heca.misc.logger:warning:33 - No tapas policy found at given path: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/faucet0_b_a/policy_gt.pt

# %%
demos = agent.load_demos(segment_ids)
# Out:
# 2026-08-17 13:59:47.260 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 69 using strategy mean-length.
# n_trajs 5
# n_frames 12

# %%
agent.fit_stage1(demos)
# Out:
# 2026-08-17 13:59:47.266 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 13:59:47.266 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 13:59:47.266 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2860 - Segmenting trajectories
# 2026-08-17 13:59:47.567 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(19, dtype=torch.int32),) from traj 1 of len 88
# 2026-08-17 13:59:47.567 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# ...

# %%
agent.plot_stage1()
# Out:
# 2026-08-17 13:59:51.992 | INFO     | tapas_gmm_modified.policy.models.tpgmm:plot_model:3856 - Did not specify time_based, deciding automatically.

# %%
agent.fit_stage2(demos)
# Out:
# 2026-08-17 13:59:53.667 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 13:59:53.667 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 13:59:53.671 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# 2026-08-17 13:59:53.671 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_hmm:1296 - HMM EM ...
# 2026-08-17 13:59:53.677 | INFO     | riepybdlib.statistics:trans:1710 - HMM transition matrix not defined, initializing to uniform
# HMM EM:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-08-17 13:59:53.751 | INFO     | riepybdlib.statistics:init_priors:1698 - HMM init priors not defined, initializing to uniform
# 2026-08-17 14:00:18.518 | INFO     | riepybdlib.statistics:em:2249 - HMM EM converged

# %%
agent.plot_stage2()

# %%
agent.save()
# Out:
# 2026-08-17 14:00:20.398 | INFO     | heca.misc.logger:info:37 - Saving <class 'heca.experts.tapas.TapasExpert'> to /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 14:00:20.398 | INFO     | heca.misc.logger:info:37 - Saving tapas policy to: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/faucet0_b_a/policy_gt.pt
# 2026-08-17 14:00:20.398 | INFO     | tapas_gmm_modified.policy.models.tpgmm:to_disk:2617 - Saving model:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.save()
#
# File ~/Documents/GitHub/heca/src/heca/misc/base.py:152, in Persistable.save(self)
#     150 path = self.save_dir(self.cfg)
#     151 logger.info(f"Saving {type(self)} to {path}")
# --> 152 self._save(path)
#
# File ~/Documents/GitHub/heca/src/heca/experts/tapas.py:206, in TapasExpert._save(self, path)
# ...
