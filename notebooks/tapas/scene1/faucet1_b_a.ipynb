# %%
from heca.experts.tapas import TapasExpert
from conf.experts.scene1 import faucet1_b_a as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# 2026-08-17 15:29:10.028 | INFO     |  Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/riepybdlib/data.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_listdir
# 2026-08-17 15:29:12.050 | INFO     | heca.misc.logger:info:37 - Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
agent = TapasExpert.get(agent_cfg)
# Out:
# 2026-08-17 15:29:13.050 | INFO     | heca.misc.logger:info:37 - Loading <class 'heca.experts.tapas.TapasExpert'> from /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 15:29:13.050 | INFO     | tapas_gmm_modified.utils.logging:wrapper:67 - Initializing Policy:
# 2026-08-17 15:29:13.050 | INFO     | tapas_gmm_modified.encoder:get_image_encoder_class:62 - No encoder config provided. Using None.
# 2026-08-17 15:29:13.051 | WARNING  | heca.misc.logger:warning:33 - No tapas policy found at given path: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/faucet1_b_a/policy_gt.pt

# %%
demos = agent.load_demos(segment_ids)
# Out:
# 2026-08-17 15:29:15.170 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 65 using strategy mean-length.
# n_trajs 5
# n_frames 12

# %%
agent.fit_stage1(demos)
# Out:
# 2026-08-17 15:29:15.183 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 15:29:15.184 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 15:29:15.184 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2860 - Segmenting trajectories
# 2026-08-17 15:29:15.473 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(23, dtype=torch.int32),) from traj 1 of len 88
# 2026-08-17 15:29:15.473 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(25, dtype=torch.int32), tensor(44, dtype=torch.int32)) from traj 2 of len 78
# 2026-08-17 15:29:15.473 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(21, dtype=torch.int32), tensor(42, dtype=torch.int32)) from traj 3 of len 89
# 2026-08-17 15:29:15.473 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2697 - Creating segement of demos.
# 2026-08-17 15:29:15.474 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length
| WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:21.275 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:21.310 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:21.654 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 12/12
# 2026-08-17 15:29:21.655 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 15:29:21.655 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 65 using strategy mean-length.
# 2026-08-17 15:29:21.656 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 15:29:21.656 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 15:29:21.656 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 15:29:21.656 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 15:29:21.829 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_init    score (rel):     -1 (1.000)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button0    score (rel):     -0 (0.197)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - shelf0     score (rel):     -0 (0.197)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet0    score (rel):     -0 (0.197)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet1    score (rel):     -0 (0.001)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - cube0      score (rel):     -0 (0.000)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button0_target score (rel):     -0 (0.197)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - shelf0_target score (rel):     -0 (0.197)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet0_target score (rel):     -0 (0.001)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet1_target score (rel):     -0 (0.000)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - cube0_target score (rel):     -0 (0.000)
# 2026-08-17 15:29:22.046 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_target  score (rel):     -0 (0.324)
# 2026-08-17 15:29:22.047 | WARNING  | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2914 - Using manual frame selection for debugging.
# 2026-08-17 15:29:22.047 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 15:29:22.047 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 65 using strategy mean-length.
# 2026-08-17 15:29:22.048 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2941 - Segmented trajs into 1 segments
# 2026-08-17 15:29:22.051 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2960 - Frame score (abs):
#             ee_init   button0    shelf0   faucet0  faucet1     cube0  \
# Segment 0 -0.984174 -0.194198 -0.194198 -0.193873 -0.00051 -0.000001
#
#            button0_target  shelf0_target  faucet0_target  faucet1_target  \
# Segment 0       -0.194198      -0.194198       -0.000557       -0.000235
#
#            cube0_target  ee_target
# Segment 0     -0.000105  -0.318702
# 2026-08-17 15:29:22.053 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2961 - Frame score (rel):
#            ee_init  button0   shelf0  faucet0   faucet1     cube0  \
# Segment 0      1.0  0.19732  0.19732  0.19699  0.000518  0.000001
#
#            button0_target  shelf0_target  faucet0_target  faucet1_target  \
# Segment 0         0.19732        0.19732        0.000566        0.000239
#
#            cube0_target  ee_target
# Segment 0      0.000106   0.323827
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 15:29:22.060 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R3 x QUAT x R1
# 2026-08-17 15:29:22.060 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 15:29:22.060 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 15:29:22.060 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 15:29:22.254 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.322 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.425 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.493 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.561 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.630 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:22.715 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.

# %%
agent.plot_stage1()
# Out:
# 2026-08-17 15:29:23.570 | INFO     | tapas_gmm_modified.policy.models.tpgmm:plot_model:3856 - Did not specify time_based, deciding automatically.

# %%
agent.fit_stage2(demos)
# Out:
# 2026-08-17 15:29:25.266 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 15:29:25.266 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 15:29:25.270 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# 2026-08-17 15:29:25.270 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_hmm:1296 - HMM EM ...
# 2026-08-17 15:29:25.279 | INFO     | riepybdlib.statistics:trans:1710 - HMM transition matrix not defined, initializing to uniform
# HMM EM:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-08-17 15:29:25.378 | INFO     | riepybdlib.statistics:init_priors:1698 - HMM init priors not defined, initializing to uniform
# 2026-08-17 15:29:27.063 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:28.193 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:29.886 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:31.025 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:32.166 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:33.320 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:34.461 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:37.141 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:38.265 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:40.305 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:41.439 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:42.581 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:43.707 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:44.837 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:47.460 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:48.616 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:49.961 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:51.114 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:52.263 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:53.405 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:29:54.544 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:01.036 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:02.176 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:04.528 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:05.977 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:09.431 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:10.634 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:11.772 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:13.818 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:15.071 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:16.792 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:21.472 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:24.306 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:27.480 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:28.957 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:32.715 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:35.441 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:37.037 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:39.751 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:42.621 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:53.282 | WARNING  | riepybdlib.statistics:__empirical_mean:317 - Gaussian mle not converged in 50 iterations.
# 2026-08-17 15:30:54.581 | INFO     | riepybdlib.statistics:em:2249 - HMM EM converged

# %%
agent.plot_stage2()

# %%
agent.save()
# Out:
# 2026-08-17 15:30:56.818 | INFO     | heca.misc.logger:info:37 - Saving <class 'heca.experts.tapas.TapasExpert'> to /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1
# 2026-08-17 15:30:56.818 | INFO     | heca.misc.logger:info:37 - Saving tapas policy to: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/faucet1_b_a/policy_gt.pt
# 2026-08-17 15:30:56.818 | INFO     | tapas_gmm_modified.policy.models.tpgmm:to_disk:2617 - Saving model:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.save()
#
# File ~/Documents/GitHub/heca/src/heca/misc/base.py:152, in Persistable.save(self)
#     150 path = self.save_dir(self.cfg)
#     151 logger.info(f"Saving {type(self)} to {path}")
# --> 152 self._save(path)
#
# File ~/Documents/GitHub/heca/src/heca/experts/tapas.py:206, in TapasExpert._save(self, path)
#     204 filepath = path / "experts" / self.cfg.tag / file_name
#     205 logger.info(f"Saving tapas policy to: {filepath}")
# --> 206 self.model.to_disk(str(filepath))
#
# File ~/miniconda3/envs/hecarim/lib/python3.10/site-packages/tapas_gmm_modified/policy/models/tpgmm.py:2619, in TPGMM.to_disk(self, file_name)
#    2616 def to_disk(self, file_name: str) -> None:
#    2617     logger.info("Saving model:")
# -> 2619     with open(file_name, "wb") as f:
#    2620         pickle.dump(self, f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene1/experts/faucet1_b_a/policy_gt.pt'
