# %%
from heca.experts.tapas import TapasExpert
from conf.experts.scene3 import button0_s1_s0 as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# 2026-08-17 14:03:17.342 | INFO     |  Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/riepybdlib/data.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_listdir
# 2026-08-17 14:03:19.358 | INFO     | heca.misc.logger:info:37 - Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
agent = TapasExpert.get(agent_cfg)
# Out:
# 2026-08-17 14:03:20.388 | INFO     | heca.misc.logger:info:37 - Loading <class 'heca.experts.tapas.TapasExpert'> from /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene3
# 2026-08-17 14:03:20.388 | INFO     | tapas_gmm_modified.utils.logging:wrapper:67 - Initializing Policy:
# 2026-08-17 14:03:20.388 | INFO     | tapas_gmm_modified.encoder:get_image_encoder_class:62 - No encoder config provided. Using None.
# 2026-08-17 14:03:20.388 | WARNING  | heca.misc.logger:warning:33 - No tapas policy found at given path: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene3/experts/button0_s1_s0/policy_gt.pt

# %%
demos = agent.load_demos(segment_ids)
# Out:
# 2026-08-17 14:03:21.646 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 33 using strategy mean-length.
# n_trajs 5
# n_frames 14

# %%
agent.fit_stage1(demos)
# Out:
# 2026-08-17 14:03:21.651 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 14:03:21.651 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:03:21.651 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2860 - Segmenting trajectories
# 2026-08-17 14:03:21.932 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2697 - Creating segement of demos.
# 2026-08-17 14:03:21.934 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 33 using strategy mean-length.
# 2026-08-17 14:03:21.934 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2865 - ... created 1 segments
# 2026-08-17 14:03:21.934 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 1/14
# 2026-08-17 14:03:21.934 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:03:21.934 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 33 using strategy mean-length.
# 2026-08-17 14:03:21.935 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:03:21.935 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:03:21.935 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:03:21.935 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:03:22.061 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 2/14
# 2026-08-17 14:03:22.062 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:03:22.062 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 33 using strategy mean-length.
# 2026-08-17 14:03:22.063 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:03:22.063 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:03:22.063 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:03:22.063 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:03:22.208 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame 3/14
# 2026-08-17 14:03:22.209 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:03:22.209 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 33 using strategy mean-length.
# 2026-08-17 14:03:22.210 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 14:03:22.210 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:03:22.211 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:03:22.211 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 14:03:22.365 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_frames:3043 - Fitting candidate frame
| INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button1_target score (rel):     -0 (0.127)
# 2026-08-17 14:03:24.122 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button2_target score (rel):     -0 (0.127)
# 2026-08-17 14:03:24.122 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - shelf0_target score (rel):     -0 (0.127)
# 2026-08-17 14:03:24.122 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - drawer0_target score (rel):     -0 (0.027)
# 2026-08-17 14:03:24.122 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - cube0_target score (rel):     -0 (0.000)
# 2026-08-17 14:03:24.122 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_target  score (rel):     -1 (0.974)
# 2026-08-17 14:03:24.123 | WARNING  | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2914 - Using manual frame selection for debugging.
# 2026-08-17 14:03:24.123 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 14:03:24.123 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 33 using strategy mean-length.
# 2026-08-17 14:03:24.124 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2941 - Segmented trajs into 1 segments
# 2026-08-17 14:03:24.127 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2960 - Frame score (abs):
#             ee_init   button0   button1   button2    shelf0   drawer0  \
# Segment 0 -0.948164 -0.120714 -0.120714 -0.120714 -0.120714 -0.209698
#
#               cube0  button0_target  button1_target  button2_target  \
# Segment 0 -0.000134       -0.120714       -0.120714       -0.120714
#
#            shelf0_target  drawer0_target  cube0_target  ee_target
# Segment 0      -0.120714       -0.025825 -1.305007e-07  -0.923496
# 2026-08-17 14:03:24.129 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2961 - Frame score (rel):
#            ee_init   button0   button1   button2    shelf0   drawer0  \
# Segment 0      1.0  0.127314  0.127314  0.127314  0.127314  0.221163
#
#               cube0  button0_target  button1_target  button2_target  \
# Segment 0  0.000142        0.127314        0.127314        0.127314
#
#            shelf0_target  drawer0_target  cube0_target  ee_target
# Segment 0       0.127314        0.027237  1.376352e-07   0.973983
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 14:03:24.134 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R3 x QUAT x R3 x QUAT x R1
# 2026-08-17 14:03:24.134 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 14:03:24.134 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 14:03:24.134 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
agent.plot_stage1()
# Out:
# 2026-08-17 14:03:24.522 | INFO     | tapas_gmm_modified.policy.models.tpgmm:plot_model:3856 - Did not specify time_based, deciding automatically.

# %%
agent.fit_stage2(demos)
# Out:
# 2026-08-17 14:03:26.643 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 14:03:26.643 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 14:03:26.646 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# 2026-08-17 14:03:26.646 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_hmm:1296 - HMM EM ...
# 2026-08-17 14:03:26.654 | INFO     | riepybdlib.statistics:trans:1710 - HMM transition matrix not defined, initializing to uniform
# HMM EM:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-08-17 14:03:26.721 | INFO     | riepybdlib.statistics:init_priors:1698 - HMM init priors not defined, initializing to uniform

# %%
agent.plot_stage2()

# %%
agent.save()
