# %%
from heca.experts.tapas import TapasExpert
from conf.experts.scene5 import faucet0_a_b as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# 2026-08-17 15:33:28.218 | INFO     |  Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/riepybdlib/data.py:34: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_listdir
# 2026-08-17 15:33:30.248 | INFO     | heca.misc.logger:info:37 - Running on cpu
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/jangruhnert/miniconda3/envs/hecarim/lib/python3.10/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
agent = TapasExpert.get(agent_cfg)
# Out:
# 2026-08-17 15:33:31.252 | INFO     | heca.misc.logger:info:37 - Loading <class 'heca.experts.tapas.TapasExpert'> from /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene5
# 2026-08-17 15:33:31.252 | INFO     | tapas_gmm_modified.utils.logging:wrapper:67 - Initializing Policy:
# 2026-08-17 15:33:31.253 | INFO     | tapas_gmm_modified.encoder:get_image_encoder_class:62 - No encoder config provided. Using None.
# 2026-08-17 15:33:31.253 | WARNING  | heca.misc.logger:warning:33 - No tapas policy found at given path: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene5/experts/faucet0_a_b/policy_gt.pt

# %%
demos = agent.load_demos(segment_ids)
# Out:
# 2026-08-17 15:33:33.734 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 67 using strategy mean-length.
# n_trajs 5
# n_frames 14

# %%
agent.fit_stage1(demos)
# Out:
# 2026-08-17 15:33:33.739 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 15:33:33.740 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 15:33:33.740 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2860 - Segmenting trajectories
# 2026-08-17 15:33:34.029 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(19, dtype=torch.int32),) from traj 1 of len 90
# 2026-08-17 15:33:34.029 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(24, dtype=torch.int32),) from traj 3 of len 81
# 2026-08-17 15:33:34.029 | WARNING  | tapas_gmm_modified.dataset.demos:_get_segmentation_indeces_velocity_based:2151 - Got different number of segmentation points for different trajectories.
# Assuming it's because of settlement time.
# Popping (tensor(19, dtype=torch.int32),) from traj 4 of len 85
# 2026-08-17 15:33:34.029 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2697 - Creating segement of demos.
# 2026-08-17 15:33:34.030 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length
| INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 15:33:37.851 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 67 using strategy mean-length.
# 2026-08-17 15:33:37.853 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R1
# 2026-08-17 15:33:37.853 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 15:33:37.853 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 15:33:37.853 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]
# 2026-08-17 15:33:38.105 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_init    score (rel):     -1 (0.972)
# 2026-08-17 15:33:38.105 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button0    score (rel):     -0 (0.178)
# 2026-08-17 15:33:38.105 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button1    score (rel):     -0 (0.178)
# 2026-08-17 15:33:38.105 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button2    score (rel):     -0 (0.178)
# 2026-08-17 15:33:38.105 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet0    score (rel):     -0 (0.000)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - drawer0    score (rel):     -0 (0.002)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - slider0    score (rel):     -0 (0.001)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button0_target score (rel):     -0 (0.178)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button1_target score (rel):     -0 (0.178)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - button2_target score (rel):     -0 (0.178)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - faucet0_target score (rel):     -0 (0.000)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - drawer0_target score (rel):     -0 (0.007)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - slider0_target score (rel):     -0 (0.001)
# 2026-08-17 15:33:38.106 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_frames:3009 - ee_target  score (rel):     -1 (1.000)
# 2026-08-17 15:33:38.106 | WARNING  | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2914 - Using manual frame selection for debugging.
# 2026-08-17 15:33:38.107 | INFO     | tapas_gmm_modified.dataset.demos:__init__:2470 - Creating partial frame view of demos.
# 2026-08-17 15:33:38.107 | INFO     | tapas_gmm_modified.dataset.demos:subsample_to_common_length:609 - Subsampling to length 67 using strategy mean-length.
# 2026-08-17 15:33:38.108 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2941 - Segmented trajs into 1 segments
# 2026-08-17 15:33:38.111 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2960 - Frame score (abs):
#            ee_init   button0   button1   button2   faucet0   drawer0  \
# Segment 0 -0.90765 -0.166196 -0.166196 -0.166196 -0.000011 -0.002194
#
#             slider0  button0_target  button1_target  button2_target  \
# Segment 0 -0.001092       -0.166196       -0.166196       -0.166196
#
#            faucet0_target  drawer0_target  slider0_target  ee_target
# Segment 0       -0.000407       -0.006708       -0.000603  -0.934204
# 2026-08-17 15:33:38.113 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_segment_and_frame_select:2961 - Frame score (rel):
#             ee_init   button0   button1   button2   faucet0   drawer0  \
# Segment 0  0.971576  0.177902  0.177902  0.177902  0.000011  0.002348
#
#             slider0  button0_target  button1_target  button2_target  \
# Segment 0  0.001169        0.177902        0.177902        0.177902
#
#            faucet0_target  drawer0_target  slider0_target  ee_target
# Segment 0        0.000435        0.007181        0.000646        1.0
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 15:33:38.126 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_setup_manifold:735 - Manifold: TIME x R3 x QUAT x R3 x QUAT x R1
# 2026-08-17 15:33:38.126 | INFO     | riepybdlib.statistics:set_n_components:779 - Changing number of components to 20
# 2026-08-17 15:33:38.127 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [INIT]
# 2026-08-17 15:33:38.127 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_init:1195 - Model init ...
# Time-based init:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
agent.plot_stage1()
# Out:
# 2026-08-17 15:33:38.827 | INFO     | tapas_gmm_modified.policy.models.tpgmm:plot_model:3856 - Did not specify time_based, deciding automatically.

# %%
agent.fit_stage2(demos)
# Out:
# 2026-08-17 15:33:40.516 | INFO     | tapas_gmm_modified.policy.models.tpgmm:fit_trajectories:2740 - Fitting AutoTPGMM
# 2026-08-17 15:33:40.516 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# Fitting segments:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-08-17 15:33:40.520 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_select_fitting_actions:1088 - Performing fitting actions: [EM_HMM]
# 2026-08-17 15:33:40.521 | INFO     | tapas_gmm_modified.policy.models.tpgmm:_fit_rbd_hmm:1296 - HMM EM ...
# 2026-08-17 15:33:40.527 | INFO     | riepybdlib.statistics:trans:1710 - HMM transition matrix not defined, initializing to uniform
# HMM EM:   0%|          | 0/50 [00:00<?, ?it/s]
# 2026-08-17 15:33:40.624 | INFO     | riepybdlib.statistics:init_priors:1698 - HMM init priors not defined, initializing to uniform
# 2026-08-17 15:34:10.776 | INFO     | riepybdlib.statistics:em:2249 - HMM EM converged

# %%
agent.plot_stage2()

# %%
agent.save()
# Out:
# 2026-08-17 15:34:12.678 | INFO     | heca.misc.logger:info:37 - Saving <class 'heca.experts.tapas.TapasExpert'> to /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene5
# 2026-08-17 15:34:12.678 | INFO     | heca.misc.logger:info:37 - Saving tapas policy to: /home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene5/experts/faucet0_a_b/policy_gt.pt
# 2026-08-17 15:34:12.678 | INFO     | tapas_gmm_modified.policy.models.tpgmm:to_disk:2617 - Saving model:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 agent.save()
#
# File ~/Documents/GitHub/heca/src/heca/misc/base.py:152, in Persistable.save(self)
#     150 path = self.save_dir(self.cfg)
#     151 logger.info(f"Saving {type(self)} to {path}")
# --> 152 self._save(path)
#
# File ~/Documents/GitHub/heca/src/heca/experts/tapas.py:206, in TapasExpert._save(self, path)
#     204 filepath = path / "experts" / self.cfg.tag / file_name
#     205 logger.info(f"Saving tapas policy to: {filepath}")
# --> 206 self.model.to_disk(str(filepath))
#
# File ~/miniconda3/envs/hecarim/lib/python3.10/site-packages/tapas_gmm_modified/policy/models/tpgmm.py:2619, in TPGMM.to_disk(self, file_name)
#    2616 def to_disk(self, file_name: str) -> None:
#    2617     logger.info("Saving model:")
# -> 2619     with open(file_name, "wb") as f:
#    2620         pickle.dump(self, f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jangruhnert/Documents/GitHub/heca/data/scenes/ogbench/scene5/experts/faucet0_a_b/policy_gt.pt'
