# %%
from heca.experts.tapas import TapasExpert
from conf.experts.sceneog import close_drawer as agent_cfg
segment_ids = [0, 1, 3, 4, 5]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from heca.experts.tapas import TapasExpert
# ----> 2 from conf.experts.sceneog import close_drawer as agent_cfg
#       3 segment_ids = [0, 1, 3, 4, 5]
#
# ModuleNotFoundError: No module named 'conf.experts'

# %%
agent = TapasExpert.get(agent_cfg)

# %%
demos = agent.load_demos(segment_ids)

# %%
agent.fit_stage1(demos)

# %%
agent.plot_stage1()

# %%
agent.fit_stage2(demos)

# %%
agent.plot_stage2()

# %%
agent.save()
